# %%
import sys
import os

path = os.getcwd()

sys.path.append(f'{path}/src/')

os.getcwd()

sys.path.insert(1, os.path.join(sys.path[0], '../src'))

# %%
from img_processing.img_to_graph import *
from img_processing.img_tools import *
from path_generator.path_tools import *

# %%
path = f'{path}/test_images/n05.jpg'

# %%
G, centres = img_to_graph(path, print_image=True)
draw_graph(G)

# %%
# reduce to single connections
solution = create_random_array(len(centres))

# %%
#TODO: make this work

graph_from_solution(centres, solution, draw_graph=True)
# Out:
# 0 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 graph_from_solution(centres, solution, draw_graph=True)
#
# File ~/git/simula_proj/src/path_generator/path_tools.py:125, in graph_from_solution(solution, centres, draw_graph, start_zero)
#     123     for j in range(i + 1, centres_len):
#     124         print(i, j)
# --> 125         cost_matrix[i, j] = cost_matrix[j, i] = get_euclidean_distance(centres[i], centres[j])
#     127 # Calculate the total distance, distances between nodes, and the angles of the edges
#     128 total_distance = 0
#
# File ~/git/simula_proj/src/path_generator/path_tools.py:18, in get_euclidean_distance(point1, point2)
#       8 def get_euclidean_distance(point1, point2):
#       9     """Get Euclidean distance between two points.
#      10
#      11     Args:
#    (...)
#      16         float: Euclidean distance between point 1 and point 2.
#      17     """
# ---> 18     return math.sqrt((point2[0] - point1[0])**2 + (point2[1] - point1[1])**2)
#
# TypeError: 'int' object is not subscriptable
