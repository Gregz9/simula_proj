# %% [markdown]
# Test get_instructions -OK

# %%
import sys
import os

path = os.getcwd()
sys.path.append(f'{path}/src/')
os.getcwd()

sys.path.insert(1, os.path.join(sys.path[0], '../src'))
path = f'{path}/test_images/n09.jpg'
path
# Out:
# '/home/frida/git/simula_proj/test_images/n09.jpg'

# %%
from path_generator.send_instructions import get_instructions

# %%
instruction_json = get_instructions(path, spatial=True, show_graph=True, show_solution=True)
# Out:
# New width: 2736
# New height: 3360
# solution before: [3, 2, 1, 8, 7, 6, 5, 4, 0]
# solution after: [0, 3, 2, 1, 8, 7, 6, 5, 4]
# [0, 3, 2, 1, 8, 7, 6, 5, 4]
# Turn 0.00 degrees
# Move 8.00 cm
# Turn 20.74 degrees
# Move 35.34 cm
# Turn 142.49 degrees
# Move 15.50 cm
# Turn 93.29 degrees
# Move 37.90 cm
# Turn -216.92 degrees
# Move 87.98 cm
# Turn 225.10 degrees
# Move 59.28 cm
# Turn -130.77 degrees
# Move 24.07 cm
# Turn 131.74 degrees
# Move 25.21 cm
# Turn -174.68 degrees
# Move 60.41 cm
# Turn 120.42 degrees
# Move 51.21 cm

# %% [markdown]
# Test capture and send - TODO

# %%
import socket   
hostname=socket.gethostname()   
IPAddr=socket.gethostbyname(hostname)   
print("Your Computer Name is:"+hostname)   
print("Your Computer IP Address is:"+IPAddr)
# Out:
# Your Computer Name is:L340
# Your Computer IP Address is:192.168.50.154

# %%
from path_generator.send_instructions import capture_and_send_instructions

# %%
capture_and_send_instructions()
# Out:
# New width: 2736
# New height: 3360
# Turn 0.00 degrees
# Move 8.00 cm
# Turn 39.54 degrees
# Move 74.41 cm
# Turn 225.10 degrees
# Move 45.92 cm
# Turn -130.85 degrees
# Move 42.52 cm
# Turn 99.99 degrees
# Move 40.08 cm
# Instructions sent: [{"action": "Turn", "value": 0}, {"action": "Move", "value": 8}, {"action": "Turn", "value": 39.54}, {"action": "Move", "value": 74.41}, {"action": "Turn", "value": 225.1}, {"action": "Move", "value": 45.92}, {"action": "Turn", "value": -130.85}, {"action": "Move", "value": 42.52}, {"action": "Turn", "value": 99.99}, {"action": "Move", "value": 40.08}]
