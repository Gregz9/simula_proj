# %% [markdown]
# Test get_instructions

# %%
import sys
import os

path = os.getcwd()
sys.path.append(f'{path}/src/')
os.getcwd()

sys.path.insert(1, os.path.join(sys.path[0], '../src'))
path = f'{path}/test_images/n05.jpg'

# %%
from path_generator.send_instructions import get_instructions

# %%
get_instructions(path, spatial=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_instructions(path, spatial=True)
#
# File ~/git/simula_proj/src/path_generator/send_instructions.py:62, in get_instructions(image_file, spatial)
#      59 solution = create_random_array(len(G)) # return just a random path for now
#      61 # step 3: get the directions from the path
# ---> 62 solution_sorted, total_distance, node_distances, edge_angles = graph_from_solution(G, solution)
#      64 # step 4: give directions to the rover
#      65 directions = give_directions(solution_sorted, edge_angles, node_distances)
#
# File ~/git/simula_proj/src/path_generator/path_tools.py:144, in graph_from_solution(G, solution, draw_graph, start_zero)
#     142     node_distance = G[solution[-1]][solution[0]]['weight']
#     143 else:  # The distance is between the current and previous nodes in the solution
# ...
