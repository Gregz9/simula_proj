# %% [markdown]
# Test get_instructions -OK

# %%
import sys
import os

path = os.getcwd()
sys.path.append(f'{path}/src/')
os.getcwd()

sys.path.insert(1, os.path.join(sys.path[0], '../src'))
path = f'{path}/test_images/n09.jpg'

# %%
from path_generator.send_instructions import get_instructions

# %%
instruction_json = get_instructions(path, spatial=True, show_graph=True, show_solution=True)
# Out:
# solution before: [7, 2, 1, 5, 0, 8, 4, 3, 6]
# solution after: [0, 8, 4, 3, 6, 7, 2, 1, 5]
# [0, 8, 4, 3, 6, 7, 2, 1, 5]
# Turn 0.00 degrees
# Move 8.00 cm
# Turn 22.41 degrees
# Move 72.07 cm
# Turn 160.72 degrees
# Move 23.77 cm
# Turn 51.16 degrees
# Move 16.82 cm
# Turn -280.93 degrees
# Move 18.38 cm
# Turn 0.57 degrees
# Move 24.07 cm
# Turn 187.54 degrees
# Move 57.95 cm
# Turn 115.05 degrees
# Move 37.90 cm
# Turn -266.60 degrees
# Move 34.94 cm
# Turn 159.38 degrees
# Move 56.91 cm
